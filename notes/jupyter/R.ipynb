# %% [markdown]
# # restart session
#
# .rs.restartR()
#
# # clear console
#
# ctrl + L
#
# # clear env variables
#
# rm (list = ls())
#
# # change language
#
# sys.setenv(LANG="en")
#
#
# # working with directories
#
# getwd()
#
# setwd()
#
# list.files()
#
# # Basic math
#
# #comparision
#
# (0.5-0.4) == 0.1
#
# #why this give false ??
#
# sprintf("%.54f",1.1-0.2)
#
# #[1] "0.900000000000000133226762955018784850835800170898437500"
#
# sprintf("%.54f",0.9)
# #[1] "0.900000000000000022204460492503130808472633361816406250"
# #Solution is to use the function all.equal(x,y) or sprintf("%.1f", 0.5-0.4) == 0.1
#
#
#
# # Importing data
#
# #deal with missing values
# #fill = T
#
# read.table(file = 'data/missing.txt', header = T, sep = ",", stringsAsFactors = F, fill = T)
#
# #replace missing values
# #na.strings = c("?","","NA")
# fp <- read.table(file = 'data/missing.txt', header = T, sep = ",", stringsAsFactors = F, fill = T, na.strings = c("?","","NA"))
#
#
# #Read fixed wdth files
#
# data3 <- read_fwf(file = "data.txt", fwf_cols(price=c(1,4), stock=c(5,14), purchased=c(18,18)), skip=1)
#
# ##dealing with excel file
#
# #make sure to set not available, so readxl can convert datatype correctly
# #datatypes hierachy char, double, int, logical (if NA in one row so it convert it to char)
# read_excel("example.xls", sheet = "missing", na = c("?","","NA"))
#
# ##handle html table in webpages
# install.packages('rvest')
# library(rvest)
#
# webpage <- read_html('url')
# #search for table webpages nodes
# tblNodes <- html_nodes(webpage, 'table')
#
# #convert table to dataframe
# #get a list of dataframes,
# tblist <- html_table(tblNodes)
#
#
# allmissing <- is.na(dataset)
# counts <- colSums(allmissing)
# counts[counts > 0]
#
# # VISUALISATION
#
# opaque != transparent
#
# aestethics : color, shape, size
#
# color helps us get that insight in the data
